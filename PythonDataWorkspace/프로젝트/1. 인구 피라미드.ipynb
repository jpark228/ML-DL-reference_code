# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
file_name = '202106_202108_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_m.head(3)
# Out:
# C:\Users\junkyu\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       818,846  1,159,925  1,212,446  1,237,490  1,662,955  1,877,761
# 서울특별시    131,847    177,422    190,058    202,628    293,655    403,275
# 부산광역시     47,188     68,647     67,987     70,204    103,526    116,957
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,647,959  1,846,656  2,014,362  2,162,252  ...  2,084,580
# 서울특별시      363,444    362,270    361,537    382,225  ...    350,864
# 부산광역시       99,077    111,533    125,016    130,043  ...    133,519
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       2,023,185  1,405,044  983,241  686,066  443,460  187,223  47,341
# 서울특별시      344,760    254,985  184,560  132,587   80,024   31,549   8,492
# 부산광역시      144,903    111,549   79,397   53,396   31,740   11,576   2,691
#
#         95~99세 100세 이상
# 행정기관
# 전국       9,017   2,220
# 서울특별시    1,830     619
# 부산광역시      429     149
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int) # 1,195, 951 -> 1195951 (정수형)

# %%
df_m.iloc[0]
# Out:
# 0~4세        818846
# 5~9세       1159925
# 10~14세     1212446
# 15~19세     1237490
# 20~24세     1662955
# 25~29세     1877761
# 30~34세     1647959
# 35~39세     1846656
# 40~44세     2014362
# 45~49세     2162252
# 50~54세     2258004
# 55~59세     2084580
# 60~64세     2023185
# 65~69세     1405044
# 70~74세      983241
# 75~79세      686066
# 80~84세      443460
# 85~89세      187223
# 90~94세       47341
# 95~99세        9017
# 100세 이상       2220
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w.head(3)
# Out:
# C:\Users\junkyu\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       776,687  1,103,771  1,143,036  1,148,598  1,530,716  1,673,881
# 서울특별시    124,270    168,987    180,027    193,859    323,983    422,295
# 부산광역시     44,864     65,017     64,275     65,613     97,385    106,204
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,518,464  1,762,029  1,942,535  2,097,114  ...  2,034,652
# 서울특별시      365,022    361,592    367,324    389,985  ...    362,655
# 부산광역시       92,992    107,424    121,088    129,702  ...    142,376
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       2,069,220  1,504,366  1,120,994  904,010  726,018  425,642  161,524
# 서울특별시      380,524    289,535    216,802  162,100  112,444   60,906   24,432
# 부산광역시      160,564    125,657     93,664   67,716   50,100   26,264    9,593
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        37,475     8,557
# 서울특별시      6,054     1,850
# 부산광역시      2,114       609
#
# [3 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 칼럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int) # 1,195, 951 -> 1195951 (정수형)
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          776687  1103771  1143036  1148598  1530716  1673881  1518464
# 서울특별시      124,270  168,987  180,027  193,859  323,983  422,295  365,022
# 부산광역시       44,864   65,017   64,275   65,613   97,385  106,204   92,992
# 대구광역시       33,895   50,332   51,641   54,015   73,555   73,993   62,403
# 인천광역시       44,422   63,544   66,103   65,911   87,682  101,684   89,889
# 광주광역시       22,850   33,822   36,303   37,965   50,467   48,956   39,965
# 대전광역시       22,042   31,667   34,039   35,557   49,661   50,656   42,635
# 울산광역시       18,883   27,249   27,058   25,390   30,106   31,496   30,504
# 세종특별자치시      9,997   12,958   12,476    9,447    8,181   10,457   13,478
# 경기도        227,744  320,195  326,203  317,945  409,158  447,989  420,493
# 강원도         21,278   28,950   31,486   33,489   40,311   37,192   34,686
# 충청북도        24,484   34,269   35,566   35,197   43,910   43,569   40,470
# 충청남도        33,868   47,910   49,220   47,584   54,364   53,182   54,007
# 전라북도        23,775   36,516   40,591   42,344   50,863   45,456   39,577
# 전라남도        25,884   36,815   39,186   40,173   45,784   41,306   37,568
# 경상북도        36,866   52,258   52,811   53,434   62,550   59,139   57,708
# 경상남도        49,888   76,127   78,653   74,616   83,644   80,749   79,582
# 제주특별자치도     11,677   17,155   17,398   16,059   19,112   19,558   17,485
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1762029  1942535  2097114  ...  2034652  2069220  1504366  1120994
# 서울특별시      361,592  367,324  389,985  ...  362,655  380,524  289,535  216,802
# 부산광역시      107,424  121,088  129,702  ...  142,376  160,564  125,657   93,664
# 대구광역시       75,330   89,045  101,851  ...  103,071  100,463   75,890   56,231
# 인천광역시      103,498  113,597  121,057  ...  124,125  117,226   77,567   54,321
# 광주광역시       49,319   57,499   62,204  ...   54,514   52,394   35,752   29,828
# 대전광역시       48,552   55,579   61,613  ...   55,648   56,528   39,639   27,990
# 울산광역시       38,721   43,447   47,222  ...   48,365   45,280   29,933   19,005
# 세종특별자치시     17,833   18,964   15,759  ...    9,799    9,588    6,634    4,407
# 경기도        498,166  549,416  578,701  ...  516,207  484,113  327,467  232,347
# 강원도         42,752   50,072   57,393  ...   64,175   73,297   53,153   36,986
# 충청북도        49,510   54,205   60,659  ...   63,255   68,151   49,232   33,811
# 충청남도        67,278   73,732   78,566  ...   77,081   82,975   62,819   49,703
# 전라북도        49,982   58,970   68,854  ...   69,816   75,784   57,546   50,934
# 전라남도        48,423   55,941   63,097  ...   72,736   78,851   59,558   54,864
# 경상북도        74,843   84,638   96,912  ...  109,785  118,969   94,481   70,877
# 경상남도       105,849  122,787  135,325  ...  135,196  140,446  102,181   75,732
# 제주특별자치도     22,957   26,231   28,214  ...   25,848   24,067   17,322   13,492
#
#             75~79세   80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          904010   726018  425642  161524  37475    8557
# 서울특별시      162,100  112,444  60,906  24,432  6,054   1,850
# 부산광역시       67,716   50,100  26,264   9,593  2,114     609
# 대구광역시       42,482   33,553  18,443   6,328  1,295     299
# 인천광역시       42,276   32,741  19,573   7,918  1,965     411
# 광주광역시       22,381   16,975   9,533   3,820    881     207
# 대전광역시       21,907   16,782  10,044   3,751    827     168
# 울산광역시       13,145    9,862   5,689   2,095    508      71
# 세종특별자치시      3,375    2,863   1,966     856    159      29
# 경기도        186,296  145,113  84,368  32,755  7,912   1,756
# 강원도         36,603   30,808  17,147   7,127  1,745     347
# 충청북도        31,754   27,200  16,981   6,005  1,323     245
# 충청남도        43,403   39,755  26,465   9,246  2,096     430
# 전라북도        43,835   37,682  24,295   9,170  1,879     442
# 전라남도        51,776   48,654  28,572  10,951  2,530     533
# 경상북도        62,139   57,502  35,561  12,768  2,816     557
# 경상남도        61,495   54,314  33,222  12,091  2,508     417
# 제주특별자치도     11,327    9,670   6,613   2,618    863     186
#
# [18 rows x 21 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # 단위: 천 명
plt.barh(df_w.columns, df_w.iloc[0] // 1000) 
plt.title('2021 대한민국 인구 피라미드')
plt.savefig('2021_인구피라미드.png', dpi=100)
plt.show()
