# %% [markdown]
# # 변수 (variables)

# %%
x = 1
y = 2

print(x)
print(y)
# Out:
# 1
# 2

# %%
z = "안녕"
print(z)
# Out:
# 안녕

# %% [markdown]
# # 타입 (Type)

# %% [markdown]
# 숫자

# %%
x = 1
y = 1
z = 1.2

print(x + y)
print(x - y)
print(x * y)
print(x ** y)
print(x % y) #mod
# Out:
# 2
# 0
# 1
# 1
# 0

# %% [markdown]
# 문자

# %%
z = """
    안녕하세요
    워니입니다
    """

print(z)
# Out:
#     안녕하세요
#     워니입니다

# %%
print("안녕" + "잘 지내니")
# Out:
# 안녕잘 지내니

# %%
print("너 혹시 몇살이니? " + str(4))
# Out:
# 너 혹시 몇살이니? 4

# %%
x = 4 # 숫자 타입
y = "4" # 문자 타입

print(str(x) + y)
print(x + int(y))
# Out:
# 44
# 8

# %% [markdown]
# Boolean (True/False)

# %%
x = True
y = False

print(x)
print(y)
# Out:
# True
# False
