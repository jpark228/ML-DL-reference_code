# %% [markdown]
# # 0.사전준비

# %%
#파일다운로드

#pc/colab용
# !pip install gdown==4.5.1
import gdown
import zipfile
google_path = "https://drive.google.com/uc?id="
file_id = '1HYrvZk1vbv_BAhGIghR2U15j4Vuxbp1K'
output_name = "mail.zip"
gdown.download(google_path+file_id,output_name,quiet=False)
fantasy_zip = zipfile.ZipFile("mail.zip")
fantasy_zip.extractall()

# https://drive.google.com/file/d/1HYrvZk1vbv_BAhGIghR2U15j4Vuxbp1K/view?usp=sharing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14951 sha256=5a87c5d1bf1b4ffa6753f382c48b8569f4e33b897079d3eb3659c479b9c8bedf
#   Stored in directory: /root/.cache/pip/wheels/3d/ec/b0/a96d1d126183f98570a785e6bf8789fca559853a9260e928e1
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1HYrvZk1vbv_BAhGIghR2U15j4Vuxbp1K
# To: /content/mail.zip
# 100%|██████████| 26.8M/26.8M [00:00<00:00, 27.9MB/s]

# %% [markdown]
# # 1.현업적용코드보기

# %% [markdown]
# Gmail을 활용하기 위한 사전 세팅
#
# ###### 3-1-1) 지메일 로그인
# ###### 3-1-2) 메일 설정 클릭(모든설정클릭)
# ###### 3-1-3) 전달 및 POP/IMAP 클릭
# ###### 3-1-4) Imap 액세스 - IMAP 사용 클릭
# ###### 3-1-5) 변경사항 저장
# --------------------------------------------------------
#
# ###### 3-2-1) https://myaccount.google.com/security
# ###### 3-2-2) google에 로그인 탭에서 2단계 인증
# ###### 3-2-3) 앱 비밀번호 클릭
# ###### 3-2-4) 앱 비밀번호 생성 (앱(메일) 선택, 기기선택)
# ###### 3-2-5) 생성된 앱 비밀번호 저장

# %%
import getpass
my_mail = input('당신의 gmail을 적어주세요 : ')
my_mail_psw = getpass.getpass('당신의 gmail을 보안 패스워드를 적어주세요 : ')

#### 1) 앞 차시에서 마든 수천개의 파일을 파이썬으로 불러오기
import os
file_list = os.listdir("명함_1/")
#### 2) 이메일주소불러오기
import pandas as pd
df = pd.read_csv('명함제작용data.csv')
df2 = df[['이름','직위',"전화번호",'이메일']]
#### 5) Gmail을 활용한 메일전송

import os
import smtplib
from email .mime .multipart import MIMEMultipart
from email .mime .text import MIMEText
from email .mime .base import MIMEBase
from email import encoders
# (본인이 운영하는 지메일주소)
smtp_user = my_mail #본인의 Gmail 주소를 집어넣어주세요
# (본인이 운영하는 지메일에서 확보가능한 password)
smtp_password = my_mail_psw #본인의 password를 집어넣어주세요
server = 'smtp.gmail.com'
port = 587
for file in file_list[:5]:
    file_nj = file.replace('.jpg','') 
#     email = df2[df2['전화번호']==file_nj]['이메일'].iloc[0]
    email = my_mail
    name = df2[df2['전화번호']==file_nj]['이름'].iloc[0]
    msg_html =f"""
    <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><span style="font-size:20px;line-height:107%;">안녕하세요.&nbsp;</span></strong></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><u><span style="font-size:20px;line-height:107%;">{name}&nbsp;</span></u></strong><strong><u><span style="font-size:20px;line-height:107%;">님 입사를 축하드립니다.&nbsp;</span></u></strong></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><span style="background:yellow;">잘 적응 하고 계신가요?</span></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>어려운 부분이 있으시면 언제든 연락(020-1234-5678)주시길 바랍니다!</em></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>명함 보내 드려요~! 앞으로도 잘 부탁드립니다</em></p>
    """ 
    msg = MIMEMultipart("alternative")
    msg ["Subject"] = f'{name}님 명함제작이 완료되었습니다.'
    msg ["From"] = smtp_user
    msg ["To"] = email
    msg .attach (
    MIMEText (
    msg_html,
    'html'
    )
    )
    #명함첨부
    attachment = open (f'명함_1/{file}', 'rb')
    part = MIMEBase ('application', 'octet-stream')
    part .set_payload ((attachment).read ())
    encoders .encode_base64 (part )
    part .add_header ('Content-Disposition', "attachment; filename= " + 'wordcloud_news2.png')
    msg .attach (part )

    #메일전송
    s = smtplib .SMTP (server , port )
    s .ehlo ()
    s .starttls ()
    s .login (smtp_user , smtp_password )
    s .sendmail (smtp_user , email , msg .as_string ())
    s .quit ()
# Out:
# 당신의 gmail을 적어주세요 : bhyunco@gmail.com
# 당신의 gmail을 보안 패스워드를 적어주세요 : ··········

# %% [markdown]
# # 2.Mail보내기 기본문법

# %% [markdown]
# ## 기본 이메일 사용법
# - 아웃룩
# - gmail

# %% [markdown]
# ## 아웃룩- win32com.client
# [PC전용]

# %%
# #Outlook 로그인 -개별설치
# #메일작성하기 (텍스트보내기)
# import win32com.client

# outlook=win32com.client.Dispatch("Outlook.Application")
# Txoutlook = outlook.CreateItem(0)
# Txoutlook.To = "" #개인 이메일 작성
# Txoutlook.CC = ""#개인 이메일 작성
# Txoutlook.Subject = "Bhyunco makes me better_outlook_text"
# Txoutlook.HTMLBody = """
# Bhyunco makes me better_outlook_text
# """

# #Txoutlook.Display(True)
# try:
#     Txoutlook.send()
# except:
#     print('')

# %%
#write your code(백견이 불여일타)

# %% [markdown]
# 절대경로 -> 컴퓨터를 기준으로 시작
# 상대경로 -> 현재 파일이 있는 폴더기준으로 바로 작성

# %%
# import os
# os.listdir()

# %%
#write your code(백견이 불여일타)

# %%
# #메일작성하기 (파일첨부)
# import win32com.client

# outlook=win32com.client.Dispatch("Outlook.Application")
# Txoutlook = outlook.CreateItem(0)
# Txoutlook.To = "" #개인 이메일 작성
# Txoutlook.CC = ""#개인 이메일 작성
# Txoutlook.Subject = "Bhyunco makes me better_outlook_text,FILE"
# Txoutlook.HTMLBody = """
# Bhyunco makes me better_outlook_text,FILE
# """
# attachment = r'' #본인컴퓨터의 절대경로에 맞게 설정해주세요
# # attachment = '명함\김가가 차장.jpg'

# Txoutlook.Attachments.Add(attachment)

# #Txoutlook.Display(True)
# try:
#     Txoutlook.Send()
# except:
#     pass

# %%
#write your code(백견이 불여일타)

# %% [markdown]
# ## Gmail 설정법
# [PC/COLAB 모두 활용가능]

# %%
#### 3) Gmail을 활용하기 위한 사전 세팅

#3-1-1) 지메일 로그인
#3-1-2) 메일 설정 클릭(모든설정클릭)
#3-1-3) 전달 및 POP/IMAP 클릭
#3-1-4) Imap 액세스 - IMAP 사용 클릭
#3-1-5) 변경사항 저장

#3-2-1) https://myaccount.google.com/security
#3-2-2) google에 로그인 탭에서 2단계 인증
#3-2-3) 앱 비밀번호 클릭
#3-2-4) 앱 비밀번호 생성 (앱(메일) 선택, 기기선택)
#3-2-5) 생성된 앱 비밀번호 저장

# %%
#### 4) Gmail을 활용한 메일전송
import getpass
my_mail = input('나의 발신이메일:')
your_mail = input('수신이메일:')
pw = getpass.getpass('Gmail 앱 비밀번호:')
import os
import smtplib
from email .mime .multipart import MIMEMultipart
from email .mime .text import MIMEText
from email .mime .base import MIMEBase
# from selenium .webdriver.chrome .options import Options
from email import encoders
# (본인이 운영하는 지메일주소)
smtp_user = my_mail #본인의 Gmail 주소를 집어넣어주세요
# (본인이 운영하는 지메일에서 확보가능한 password)
smtp_password = pw #본인의 password를 집어넣어주세요
emails = your_mail # 보내고자 하는 이메일을 적어주세요.
server = 'smtp.gmail.com'
port = 587
email = emails
msg = MIMEMultipart("alternative")
msg ["Subject"] = '안녕하세요 비현코입니다._gmail,file'
msg ["From"] = smtp_user
msg ["To"] = email
msg .attach (
MIMEText (
"비현코입니다._gmail,file",
'plain'
)
)
#명함첨부
attachment = open ('명함/김가가 차장.jpg', 'rb')
part = MIMEBase ('application', 'octet-stream')
part .set_payload ((attachment).read ())
encoders .encode_base64 (part )
part .add_header ('Content-Disposition', "attachment; filename= " + 'wordcloud_news2.png')
msg .attach (part )

#메일전송
s = smtplib .SMTP (server , port )
s .ehlo ()
s .starttls ()
s .login (smtp_user , smtp_password )
s .sendmail (smtp_user , email , msg .as_string ())
s .quit ()
# Out:
# 나의 발신이메일:bhyunco@gmail.com
# 수신이메일:bhyunco@gmail.com
# Gmail 앱 비밀번호:··········
# (221,
#  b'2.0.0 closing connection i187-20020a626dc4000000b00545832dd969sm416017pfc.145 - gsmtp')

# %%
#write your code(백견이 불여일타)

# %% [markdown]
# # 3.현업적용사례

# %% [markdown]
# ## [비현코의 설계노트]
#
# ### 1) 앞 차시에서 만든 수천개의 파일을 파이썬으로 불러오기
# ### 2) 이메일 주소불러오기
# ### 3) 파일이름을 넣으면 이메일이 반환되게 하기
# ### 4) 텍스트 파일을 HTML로 변환
# ### 5) Gmail을 활용한 메일전송(단체이메일전송)

# %%
#### 1) 앞 차시에서 마든 수천개의 파일을 파이썬으로 불러오기
import os
print("명함폴더의 파일갯수 :"+str(len(os.listdir("명함/"))))
print("명함_1폴더의 파일갯수 :"+str(len(os.listdir("명함_1/"))))
file_list = os.listdir("명함_1/")
# Out:
# 명함폴더의 파일갯수 :964
# 명함_1폴더의 파일갯수 :1000

# %%
#write your code(백견이 불여일타)

# %%
#### 2) 이메일주소불러오기
import pandas as pd
df = pd.read_csv('명함제작용data.csv')
print(len(df[['이름','직위',"전화번호",'이메일']]))
df2 = df[['이름','직위',"전화번호",'이메일']]
df2.head()
# Out:
# 1000
#     이름  직위           전화번호          이메일
# 0  장타차  부장  020-7695-2446  장타차@비현코.com
# 1  이타아  전무  020-4268-5734  이타아@비현코.com
# 2  선차다  차장  020-3838-7664  선차다@비현코.com
# 3  노타사  과장  020-9952-9605  노타사@비현코.com
# 4  형타아  대리  020-4478-9321  형타아@비현코.com

# %%
#write your code(백견이 불여일타)

# %%
#3)파일이름을 넣으면 이메일이 반환되게하기
file_list = os.listdir('명함_1/')
file_list
for file in file_list[:4]:
    print(file)
    file_nj = file.replace('.jpg','') 
    print(file_nj)
    print(df2[df2['전화번호']==file_nj]['이메일'].iloc[0])
    print(df2[df2['전화번호']==file_nj]['이름'].iloc[0])

    print("!!!!")
# Out:
# 020-1223-7661.jpg
# 020-1223-7661
# 성하카@비현코.com
# 성하카
# !!!!
# 020-3138-8150.jpg
# 020-3138-8150
# 선마차@비현코.com
# 선마차
# !!!!
# 020-7512-1244.jpg
# 020-7512-1244
# 노카하@비현코.com
# 노카하
# !!!!
# 020-7962-4386.jpg
# 020-7962-4386
# 박마타@비현코.com
# 박마타
# !!!!

# %%
#write your code(백견이 불여일타)

# %%
for file in file_list:
    file_nj = file.replace('.jpg','')
    print(df2[df2['전화번호']==file_nj]['이메일'].iloc[0])
# Out:
# 성하카@비현코.com
# 선마차@비현코.com
# 노카하@비현코.com
# 박마타@비현코.com
# 김자바@비현코.com
# 최아다@비현코.com
# 이타사@비현코.com
# 선다차@비현코.com
# 조하마@비현코.com
# 성사바@비현코.com
# 노차바@비현코.com
# 형파나@비현코.com
# 장라파@비현코.com
# 선아마@비현코.com
# 최마나@비현코.com
# 박카바@비현코.com
# 조아자@비현코.com
# 장아자@비현코.com
# 최라파@비현코.com
# 이차나@비현코.com
# 조자파@비현코.com
# 조타자@비현코.com
# 노다차@비현코.com
# 조사차@비현코.com
# 김아아@비현코.com
# 성나나@비현코.com
# 이하나@비현코.com
# 박아라@비현코.com
# 형타아@비현코.com
# 김라차@비현코.com
# 김라바@비현코.com
# 노다파@비현코.com
# 이카아@비현코.com
# 박다다@비현코.com
# 형아카@비현코.com
# 노카카@비현코.com
# 이타가@비현코.com
# 선바아@비현코.com
# 이타아@비현코.com
# 장하카@비현코.com
# 선나하@비현코.com
# 형나하@비현코.com
# 형자파@비현코.com
# 조마아@비현코.com
# 장가사@비현코.com
# 성가바@비현코.com
# 형가파@비현코.com
# 노자나@비현코.com
# 이카자@비현코.com
# 박나사@비현코.com
# 선하자@비현코.com
# 노자사@비현코.com
# 최가다@비현코.com
# 노사하@비현코.com
# 노바파@비현코.com
# 최아차@비현코.com
# 이다자@비현코.com
# 이하아@비현코.com
# 최마사@비현코.com
# 김바나@비현코.com
# 최다라@비현코.com
# 김나카@비현코.com
# 노타파@비현코.com
# 형마가@비현코.com
# 박하다@비현코.com
# 조파사@비현코.com
# 성바아@비현코.com
# 선하바@비현코.com
# 이가카@비현코.com
# 조아하@비현코.com
# 장라자@비현코.com
# ...

# %%
#write your code(백견이 불여일타)

# %%
#4)텍스트 파일을 HTML 파일로 변환 https://wordtohtml.net/
 #접속후 원하는 내용을 잘 정리

a= "비현코"
b= "020-1234-5678"

print(f'반갑습니다.{a}님 전화번호가 혹시 {b} 가 맞나요??')
# Out:
# 반갑습니다.비현코님 전화번호가 혹시 020-1234-5678 가 맞나요??

# %%
print(f"""
조금은 어렵지만
알고나면 생각보다 어렵지 않은
{a}의 파이썬 코딩
다들 시간을 저장해나가시길
"""
)
# f"""
# <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><span style="font-size:20px;line-height:107%;">안녕하세요.&nbsp;</span></strong></p>
# <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><u><span style="font-size:20px;line-height:107%;">{name}&nbsp;</span></u></strong><strong><u><span style="font-size:20px;line-height:107%;">님 입사를 축하드립니다.&nbsp;</span></u></strong></p>
# <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><span style="background:yellow;">잘 적응 하고 계신가요?</span></p>
# <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>어려운 부분이 있으시면 언제든 연락(020-1234-5678)주시길 바랍니다!</em></p>
# <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>명함 보내 드려요~! 앞으로도 잘 부탁드립니다</em></p>

# """
# Out:
# 조금은 어렵지만
# 알고나면 생각보다 어렵지 않은
# 비현코의 파이썬 코딩
# 다들 시간을 저장해나가시길

# %%
#write your code(백견이 불여일타)

# %%
#### 5) Gmail을 활용한 메일전송
import getpass
my_mail = input('나의 발신이메일:')
your_mail = input('수신이메일:')
pw = getpass.getpass('Gmail 앱 비밀번호:')
import os
import smtplib
from email .mime .multipart import MIMEMultipart
from email .mime .text import MIMEText
from email .mime .base import MIMEBase
from email import encoders
# (본인이 운영하는 지메일주소)
smtp_user = my_mail #본인의 Gmail 주소를 집어넣어주세요
# (본인이 운영하는 지메일에서 확보가능한 password)
smtp_password = pw #본인의 password를 집어넣어주세요
# emails = 'bhyunco@gmail.com' # 보내고자 하는 이메일을 적어주세요.
server = 'smtp.gmail.com'
port = 587

for file in file_list[:5]:
    file_nj = file.replace('.jpg','') 
#     email = df2[df2['전화번호']==file_nj]['이메일'].iloc[0]
    email = your_mail
    name = df2[df2['전화번호']==file_nj]['이름'].iloc[0]
    msg_html =f"""
    <p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><span style="font-size:20px;line-height:107%;">안녕하세요.&nbsp;</span></strong></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><strong><u><span style="font-size:20px;line-height:107%;">{name}&nbsp;</span></u></strong><strong><u><span style="font-size:20px;line-height:107%;">님 입사를 축하드립니다.&nbsp;</span></u></strong></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><span style="background:yellow;">잘 적응 하고 계신가요?</span></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>어려운 부분이 있으시면 언제든 연락(020-1234-5678)주시길 바랍니다!</em></p>
<p style='margin-top:0cm;margin-right:0cm;margin-bottom:8.0pt;margin-left:0cm;text-align:justify;line-height:107%;font-size:13px;font-family:"맑은 고딕";'><em>명함 보내 드려요~! 앞으로도 잘 부탁드립니다</em></p>
    """ 

    msg = MIMEMultipart("alternative")
    msg ["Subject"] = f'{name}님 명함제작이 완료되었습니다.'
    msg ["From"] = smtp_user
    msg ["To"] = email
    msg .attach (
    MIMEText (
    msg_html,
    'html'
    )
    )
    #명함첨부
    attachment = open (f'명함_1/{file}', 'rb')
    part = MIMEBase ('application', 'octet-stream')
    part .set_payload ((attachment).read ())
    encoders .encode_base64 (part )
    part .add_header ('Content-Disposition', "attachment; filename= " + 'wordcloud_news2.png')
    msg .attach (part )

    #메일전송
    s = smtplib .SMTP (server , port )
    s .ehlo ()
    s .starttls ()
    s .login (smtp_user , smtp_password )
    s .sendmail (smtp_user , email , msg .as_string ())
    s .quit ()
# Out:
# 나의 발신이메일:bhyunco@gmail.com
# 수신이메일:bhyunco@gmail.com
# Gmail 앱 비밀번호:··········

# %%
#write your code(백견이 불여일타)
