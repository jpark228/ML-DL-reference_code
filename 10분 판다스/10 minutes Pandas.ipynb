# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns =list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673
# 2013-01-06  1.709749  0.655181  0.302657  1.926737

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673
# 2013-01-06  1.709749  0.655181  0.302657  1.926737

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.37315163, -0.80594263, -1.4298012 , -1.68696846],
#        [-0.69924297,  1.06981364, -1.27618403,  2.47969685],
#        [ 0.48703886, -0.57009021,  0.90857084,  0.49030405],
#        [-1.04266189,  0.78905942,  1.08136078, -0.79383329],
#        [ 0.37010711, -0.60976085, -1.54955585,  1.13567252],
#        [ 1.70974939,  0.65518073,  0.30265715,  1.92673663]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.199690  0.088043 -0.327159  0.591935
# std    0.977087  0.836208  1.226242  1.597816
# min   -1.042662 -0.805943 -1.549556 -1.686968
# 25%   -0.431905 -0.599843 -1.391397 -0.472799
# 50%    0.371629  0.042545 -0.486763  0.812988
# 75%    0.458567  0.755590  0.757092  1.728971
# max    1.709749  1.069814  1.081361  2.479697

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.373152   -0.699243    0.487039   -1.042662    0.370107    1.709749
# B   -0.805943    1.069814   -0.570090    0.789059   -0.609761    0.655181
# C   -1.429801   -1.276184    0.908571    1.081361   -1.549556    0.302657
# D   -1.686968    2.479697    0.490304   -0.793833    1.135673    1.926737

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.686968 -1.429801 -0.805943  0.373152
# 2013-01-02  2.479697 -1.276184  1.069814 -0.699243
# 2013-01-03  0.490304  0.908571 -0.570090  0.487039
# 2013-01-04 -0.793833  1.081361  0.789059 -1.042662
# 2013-01-05  1.135673 -1.549556 -0.609761  0.370107
# 2013-01-06  1.926737  0.302657  0.655181  1.709749

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304
# 2013-01-06  1.709749  0.655181  0.302657  1.926737
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697

# %%
df["A"]
# Out:
# 2013-01-01    0.373152
# 2013-01-02   -0.699243
# 2013-01-03    0.487039
# 2013-01-04   -1.042662
# 2013-01-05    0.370107
# 2013-01-06    1.709749
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833

# %%
df.loc[dates[0]]
# Out:
# A    0.373152
# B   -0.805943
# C   -1.429801
# D   -1.686968
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.699243  1.069814
# 2013-01-03  0.487039 -0.570090
# 2013-01-04 -1.042662  0.789059

# %%
df.loc[dates[0], "A"]
# Out:
# 0.37315163062438034

# %%
df.at[dates[0], "A"]
# Out:
# 0.37315163062438034

# %%
df. iloc[3]
# Out:
# A   -1.042662
# B    0.789059
# C    1.081361
# D   -0.793833
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.042662  0.789059
# 2013-01-05  0.370107 -0.609761

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.699243 -1.276184
# 2013-01-03  0.487039  0.908571
# 2013-01-05  0.370107 -1.549556

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.805943 -1.429801
# 2013-01-02  1.069814 -1.276184
# 2013-01-03 -0.570090  0.908571
# 2013-01-04  0.789059  1.081361
# 2013-01-05 -0.609761 -1.549556
# 2013-01-06  0.655181  0.302657

# %%
df.iloc[1,1]
# Out:
# 1.0698136418873783

# %%
df.iat[1,1]
# Out:
# 1.0698136418873783

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673
# 2013-01-06  1.709749  0.655181  0.302657  1.926737

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.373152       NaN       NaN       NaN
# 2013-01-02       NaN  1.069814       NaN  2.479697
# 2013-01-03  0.487039       NaN  0.908571  0.490304
# 2013-01-04       NaN  0.789059  1.081361       NaN
# 2013-01-05  0.370107       NaN       NaN  1.135673
# 2013-01-06  1.709749  0.655181  0.302657  1.926737

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.373152 -0.805943 -1.429801 -1.686968    one
# 2013-01-02 -0.699243  1.069814 -1.276184  2.479697    one
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304    two
# 2013-01-04 -1.042662  0.789059  1.081361 -0.793833  three
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673   four
# 2013-01-06  1.709749  0.655181  0.302657  1.926737  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.487039 -0.570090  0.908571  0.490304   two
# 2013-01-05  0.370107 -0.609761 -1.549556  1.135673  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0,1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
# Out:
# <ipython-input-42-c9cfd4f62edf>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.429801  5  NaN
# 2013-01-02 -0.699243  1.069814 -1.276184  5  1.0
# 2013-01-03  0.487039 -0.570090  0.908571  5  2.0
# 2013-01-04 -1.042662  0.789059  1.081361  5  3.0
# 2013-01-05  0.370107 -0.609761 -1.549556  5  4.0
# 2013-01-06  1.709749  0.655181  0.302657  5  5.0

# %%
df2 = df.copy()
df2[df2>0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.429801 -5  NaN
# 2013-01-02 -0.699243 -1.069814 -1.276184 -5 -1.0
# 2013-01-03 -0.487039 -0.570090 -0.908571 -5 -2.0
# 2013-01-04 -1.042662 -0.789059 -1.081361 -5 -3.0
# 2013-01-05 -0.370107 -0.609761 -1.549556 -5 -4.0
# 2013-01-06 -1.709749 -0.655181 -0.302657 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.429801  5  NaN  1.0
# 2013-01-02 -0.699243  1.069814 -1.276184  5  1.0  1.0
# 2013-01-03  0.487039 -0.570090  0.908571  5  2.0  NaN
# 2013-01-04 -1.042662  0.789059  1.081361  5  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -0.699243  1.069814 -1.276184  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.429801  5  5.0  1.0
# 2013-01-02 -0.699243  1.069814 -1.276184  5  1.0  1.0
# 2013-01-03  0.487039 -0.570090  0.908571  5  2.0  5.0
# 2013-01-04 -1.042662  0.789059  1.081361  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.137498
# B    0.222367
# C   -0.327159
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.892550
# 2013-01-02    1.018877
# 2013-01-03    1.565104
# 2013-01-04    1.765552
# 2013-01-05    1.442158
# 2013-01-06    2.533517
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
df.agg(lambda x: np.mean(x)*5.6)
# Out:
# A     0.769991
# B     1.245256
# C    -1.832089
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x* 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000 -144.695882  506.0    NaN
# 2013-01-02  -70.763389  108.265141 -129.149824  506.0  101.2
# 2013-01-03   49.288332  -57.693129   91.947369  506.0  202.4
# 2013-01-04 -105.517383   79.852813  109.433711  506.0  303.6
# 2013-01-05   37.454839  -61.707798 -156.815052  506.0  404.8
# 2013-01-06  173.026638   66.304290   30.628904  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    2
# 1    1
# 2    0
# 3    1
# 4    2
# 5    1
# 6    6
# 7    3
# 8    0
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 2    2
# 0    2
# 6    2
# 3    1
# dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -1.719448  1.971534 -0.335024 -0.892820
# 1  0.380703  0.768365  0.595681  0.107840
# 2  0.523482  0.573973  0.127662 -0.318177
# 3  0.188342  1.033356 -3.182040 -1.017972
# 4 -2.245158 -0.644020  0.121144 -0.105917
# 5  0.482598 -0.112223  1.060982  0.678427
# 6 -1.295754  1.311943 -0.793319  2.209599
# 7  0.445542  0.528897 -1.296653 -0.903088
# 8 -0.196700 -0.974007  0.223428 -0.594510
# 9  1.440601  0.499966 -1.267560  2.348541

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.719448  1.971534 -0.335024 -0.892820
# 1  0.380703  0.768365  0.595681  0.107840
# 2  0.523482  0.573973  0.127662 -0.318177
# 3  0.188342  1.033356 -3.182040 -1.017972
# 4 -2.245158 -0.644020  0.121144 -0.105917
# 5  0.482598 -0.112223  1.060982  0.678427
# 6 -1.295754  1.311943 -0.793319  2.209599
# 7  0.445542  0.528897 -1.296653 -0.903088
# 8 -0.196700 -0.974007  0.223428 -0.594510
# 9  1.440601  0.499966 -1.267560  2.348541

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.980338 -1.161105
# 1  bar    one  0.293262  0.005231
# 2  foo    two  1.092962 -0.911592
# 3  bar  three -0.470008  1.028322
# 4  foo    two -0.873511  1.576180
# 5  bar    two -0.455162 -1.225663
# 6  foo    one  0.179848  0.711556
# 7  foo  three  2.577631 -2.654592

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.631909 -0.192111
# foo  1.996591 -2.439553

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.293262  0.005231
#     three -0.470008  1.028322
#     two   -0.455162 -1.225663
# foo one   -0.800490 -0.449549
#     three  2.577631 -2.654592
#     two    0.219450  0.664588

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     1.086799 -1.458815
#       two    -1.258085 -0.903209
# baz   one     0.739966 -0.385194
#       two     0.919492 -0.004712

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.910874  1.962089
# 1     one  B  foo  0.217133  0.508599
# 2     two  C  foo  1.401624 -1.798740
# 3   three  A  bar -0.260730 -1.201615
# 4     one  B  bar  2.023371  0.083223
# 5     one  C  bar  0.368106  0.215834
# 6     two  A  foo -0.819479  2.196678
# 7   three  B  foo  1.388393  1.492290
# 8     one  C  foo -0.944968 -1.074431
# 9     one  A  bar  0.993966 -0.182984
# 10    two  B  bar  1.695866  0.787261
# 11  three  C  bar -0.695310  1.079036

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.993966  0.910874
#       B  2.023371  0.217133
#       C  0.368106 -0.944968
# three A -0.260730       NaN
#       B       NaN  1.388393
#       C -0.695310       NaN
# two   A       NaN -0.819479
#       B  1.695866       NaN
#       C       NaN  1.401624

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24790
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.795714
# 2012-03-07    1.299236
# 2012-03-08   -1.471413
# 2012-03-09    0.954107
# 2012-03-10   -1.317009
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.795714
# 2012-03-07 00:00:00+00:00    1.299236
# 2012-03-08 00:00:00+00:00   -1.471413
# 2012-03-09 00:00:00+00:00    0.954107
# 2012-03-10 00:00:00+00:00   -1.317009
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.795714
# 2012-03-06 19:00:00-05:00    1.299236
# 2012-03-07 19:00:00-05:00   -1.471413
# 2012-03-08 19:00:00-05:00    0.954107
# 2012-03-09 19:00:00-05:00   -1.317009
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc="best");

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

# %%
df.to_csv("foo.csv")

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  2  3  1  4  0
# 1           1  2  2  0  1  3
# 2           2  1  0  2  3  3
# 3           3  0  0  3  2  0
# 4           4  3  3  4  1  0
# 5           5  2  4  1  3  3
# 6           6  4  4  4  2  2
# 7           7  2  1  0  0  1
# 8           8  4  4  3  2  2
# 9           9  3  0  1  0  0
