# %%
fruit = ["사과", "사과", "바나나", "바나나", "딸기", "키위", "복숭아", "복숭아", "복숭아"]

d = {}
# d = {"과일": 개수}

for f in fruit:

  if f in d: # "특정 과일" 라는 key 가 d 라는 딕셔너리에 들어있어?
    d[f] = d[f] + 1 # 그럼 "특정 과일" 갯수를 하나 올려줘
  else:
    d[f] = 1 # 만약 "특정 과일"이 이 없으면, 벨류를 1로 만들어줘

print(d)
# Out:
# {'사과': 2, '바나나': 2, '딸기': 1, '키위': 1, '복숭아': 3}
